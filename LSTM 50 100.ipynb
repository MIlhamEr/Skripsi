# %% [markdown]
# <a href="https://colab.research.google.com/github/MIlhamEr/Skripsi/blob/main/LSTM%2050%20100.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Import Libraries

# %%
import time
import numpy as np
import pandas as pd
import seaborn as sns
import missingno as msno
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %% [markdown]
# # Reading Dataset

# %% [markdown]
# ## ADRO

# %%
url_adro = "https://raw.githubusercontent.com/MIlhamEr/Skripsi/refs/heads/main/dataset/PT%20Adaro%20Energy%20Indonesia%20Tbk_2020-2024.csv"
adro = pd.read_csv(url_adro)
adro.head()
# Out:
#          Date    Open    High     Low   Close   Adj Close     Volume
# 0  2020-01-02  1555.0  1555.0  1490.0  1495.0  835.632202   76612000
# 1  2020-01-03  1460.0  1470.0  1425.0  1465.0  856.372375  117795600
# 2  2020-01-06  1455.0  1515.0  1450.0  1465.0  856.372375   61423200
# 3  2020-01-07  1480.0  1540.0  1460.0  1540.0  900.213867   74336500
# 4  2020-01-08  1530.0  1535.0  1505.0  1505.0  879.754395   55121100

# %%
adro.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1148 entries, 0 to 1147
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       1148 non-null   object
#  1   Open       1148 non-null   float64
#  2   High       1148 non-null   float64
#  3   Low        1148 non-null   float64
#  4   Close      1148 non-null   float64
#  5   Adj Close  1148 non-null   float64
#  6   Volume     1148 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 62.9+ KB

# %% [markdown]
# ## DSSA

# %%
url_dssa = "https://raw.githubusercontent.com/MIlhamEr/Skripsi/refs/heads/main/dataset/PT%20Dian%20Swastatika%20Sentosa%20Tbk_2020-2024.csv"
dssa = pd.read_csv(url_dssa)
dssa.head()
# Out:
#          Date    Open    High     Low   Close  Adj Close  Volume
# 0  2020-01-02  1360.0  1435.0  1360.0  1435.0     1435.0    5000
# 1  2020-01-03  1435.0  1435.0  1435.0  1435.0     1435.0       0
# 2  2020-01-06  1437.5  1437.5  1435.0  1435.0     1435.0    3000
# 3  2020-01-07  1435.0  1435.0  1435.0  1435.0     1435.0       0
# 4  2020-01-08  1435.0  1435.0  1435.0  1435.0     1435.0       0

# %%
dssa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1148 entries, 0 to 1147
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       1148 non-null   object
#  1   Open       1148 non-null   float64
#  2   High       1148 non-null   float64
#  3   Low        1148 non-null   float64
#  4   Close      1148 non-null   float64
#  5   Adj Close  1148 non-null   float64
#  6   Volume     1148 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 62.9+ KB

# %% [markdown]
# # Pre-processing Data

# %% [markdown]
# ## Normalisasi Data

# %% [markdown]
# *   Normalisasi data adro pake MinMaxScaler karena distribusinya normal
# *   Normalisasi data dssa pake StandardScaler karena terdapat outlier
# *   Kolom Date Ga dipake

# %%
scaler = MinMaxScaler()

# %%
def normalize_data(df):
    scaled_df = pd.DataFrame(scaler.fit_transform(df.iloc[:, 1:]), columns=df.columns[1:], index=df.index)
    return scaled_df

# %%
adro_norm = adro.copy()
adro_norm = normalize_data(adro_norm)
adro_norm = adro_norm.drop('Volume', axis=1)
adro_norm.head()
# Out:
#        Open      High       Low     Close  Adj Close
# 0  0.260372  0.247207  0.253602  0.243205   0.129805
# 1  0.233190  0.223464  0.234870  0.234621   0.135675
# 2  0.231760  0.236034  0.242075  0.234621   0.135675
# 3  0.238913  0.243017  0.244957  0.256080   0.148084
# 4  0.253219  0.241620  0.257925  0.246066   0.142293

# %%
dssa_norm = dssa.copy()
dssa_norm = normalize_data(dssa_norm)
dssa_norm = dssa_norm.drop('Volume', axis=1)
dssa_norm.head()
# Out:
#        Open      High       Low     Close  Adj Close
# 0  0.010859  0.011743  0.011073  0.012575   0.012575
# 1  0.012669  0.011743  0.012918  0.012575   0.012575
# 2  0.012729  0.011800  0.012918  0.012575   0.012575
# 3  0.012669  0.011743  0.012918  0.012575   0.012575
# 4  0.012669  0.011743  0.012918  0.012575   0.012575

# %% [markdown]
# ## Windowing (Time Series Data)

# %% [markdown]
# Data look back yaitu adalah data yang biasanya dipakai untuk tipe time series, data ini menjadikan nilai lookback+1 sebagai nilai prediksi , dan data lookbacknya sebagai fitur.Ini berlaku untuk seluruh data, contoh penggambarannya seperti pada gambar diatas

# %%
def prepare_data(df, time_step):
    X, y = [], []
    for i in range(len(df)-time_step):
        t = []
        for j in range(time_step):
            t.append(df.iloc[i + j].values)  # Use all columns for features
        X.append(t)
        y.append(df['High'][i + time_step]) # Predict High price
    return np.array(X), np.array(y)

# %%
time_step = 7
X_adro, y_adro = prepare_data(adro_norm, time_step)

# %%
print(X_adro)
print(y_adro)
# Out:
# [[[0.26037196 0.2472067  0.25360231 0.24320458 0.12980455]
#   [0.23319027 0.22346369 0.23487032 0.23462089 0.13567503]
#   [0.23175966 0.23603352 0.24207493 0.23462089 0.13567503]
#   ...
#   [0.25321888 0.24162011 0.25792507 0.24606581 0.14229328]
#   [0.25035765 0.23882682 0.24927954 0.24320458 0.14063873]
#   [0.25035765 0.25       0.26080692 0.25894134 0.14973887]]
#
#  [[0.23319027 0.22346369 0.23487032 0.23462089 0.13567503]
#   [0.23175966 0.23603352 0.24207493 0.23462089 0.13567503]
#   [0.23891273 0.24301676 0.24495677 0.25608011 0.1480843 ]
#   ...
#   [0.25035765 0.23882682 0.24927954 0.24320458 0.14063873]
#   [0.25035765 0.25       0.26080692 0.25894134 0.14973887]
#   [0.26895565 0.25837989 0.27233429 0.26323319 0.15222076]]
#
#  [[0.23175966 0.23603352 0.24207493 0.23462089 0.13567503]
#   [0.23891273 0.24301676 0.24495677 0.25608011 0.1480843 ]
#   [0.25321888 0.24162011 0.25792507 0.24606581 0.14229328]
#   ...
#   [0.25035765 0.25       0.26080692 0.25894134 0.14973887]
#   [0.26895565 0.25837989 0.27233429 0.26323319 0.15222076]
#   [0.26752504 0.25558659 0.26657061 0.26180258 0.15139345]]
#
#  ...
#
#  [[0.91416309 0.88547486 0.87896254 0.86552217 0.93206834]
#   [0.86552217 0.86871508 0.85302594 0.89127325 0.95754271]
#   [0.89127325 0.86871508 0.87319885 0.85979971 0.92640737]
#   ...
#   [0.86552217 0.8575419  0.87319885 0.87124464 0.93772931]
#   [0.87982833 0.8575419  0.88760807 0.87410587 0.9405598 ]
#   [0.88268956 0.86312849 0.88760807 0.88555079 0.95188174]]
#
#  [[0.86552217 0.86871508 0.85302594 0.89127325 0.95754271]
#   [0.89127325 0.86871508 0.87319885 0.85979971 0.92640737]
#   [0.86266094 0.84636872 0.85590778 0.86266094 0.92923785]
#   ...
#   [0.87982833 0.8575419  0.88760807 0.87410587 0.9405598 ]
#   [0.88268956 0.86312849 0.88760807 0.88555079 0.95188174]
#   [0.89127325 0.86312849 0.88472622 0.87124464 0.93772931]]
#
#  [[0.89127325 0.86871508 0.87319885 0.85979971 0.92640737]
#   [0.86266094 0.84636872 0.85590778 0.86266094 0.92923785]
#   [0.86552217 0.8575419  0.87319885 0.87124464 0.93772931]
#   ...
#   [0.88268956 0.86312849 0.88760807 0.88555079 0.95188174]
#   [0.89127325 0.86312849 0.88472622 0.87124464 0.93772931]
#   [0.87982833 0.86871508 0.89048991 0.89699571 0.96320368]]]
# [0.25837989 0.25558659 0.2472067  ... 0.86312849 0.86871508 0.91340782]

# %%
X_adro.shape, y_adro.shape
# Out:
# ((1141, 7, 5), (1141,))

# %%
X_dssa, y_dssa = prepare_data(dssa_norm, time_step)

# %% [markdown]
# ## Split data into training and testing sets

# %%
X_train_adro, X_test_adro, y_train_adro, y_test_adro = train_test_split(X_adro, y_adro, test_size=0.2, random_state=42, shuffle=False)
X_train_dssa, X_test_dssa, y_train_dssa, y_test_dssa = train_test_split(X_dssa, y_dssa, test_size=0.2, random_state=42, shuffle=False)

# %%
X_train_adro.shape, X_test_adro.shape, y_train_adro.shape, y_test_adro.shape
# Out:
# ((912, 7, 5), (229, 7, 5), (912,), (229,))

# %% [markdown]
# # Data Mining

# %%
def create_lstm_model(units):
    model = Sequential()
    model.add(LSTM(units=units, return_sequences=True, input_shape=(X_train_adro.shape[1], X_train_adro.shape[2])))
    model.add(Dropout(0.2))
    model.add(LSTM(units=units, return_sequences=False))
    model.add(Dropout(0.2))
    model.add(Dense(units=1))  # Output layer for single prediction (predicted stock price)
    model.compile(optimizer='adam', loss='mean_squared_error')
    return model

# %% [markdown]
# ## ADRO

# %%
model_adro = create_lstm_model(50)

start_time = time.time()
model_adro.fit(X_train_adro, y_train_adro, epochs=100, batch_size=32, validation_split=0.1)

end_time = time.time()
elapsed_time = end_time - start_time

print(f"Waktu training: {elapsed_time:.2f} detik")
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 8s 47ms/step - loss: 0.1231 - val_loss: 0.0042
# Epoch 2/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0097 - val_loss: 8.4085e-04
# Epoch 3/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0043 - val_loss: 9.7161e-04
# Epoch 4/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0040 - val_loss: 0.0011
# Epoch 5/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0034 - val_loss: 8.4863e-04
# Epoch 6/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0034 - val_loss: 8.1060e-04
# Epoch 7/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0034 - val_loss: 9.7376e-04
# Epoch 8/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0033 - val_loss: 8.1332e-04
# Epoch 9/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0029 - val_loss: 9.9462e-04
# Epoch 10/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0028 - val_loss: 0.0015
# Epoch 11/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0029 - val_loss: 0.0010
# Epoch 12/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0030 - val_loss: 8.4134e-04
# Epoch 13/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0025 - val_loss: 7.9753e-04
# Epoch 14/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0033 - val_loss: 8.9110e-04
# Epoch 15/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0023 - val_loss: 8.0229e-04
# Epoch 16/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0028 - val_loss: 7.9315e-04
# Epoch 17/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0023 - val_loss: 0.0011
# Epoch 18/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0024 - val_loss: 8.1553e-04
# Epoch 19/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0029 - val_loss: 0.0018
# Epoch 20/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0028 - val_loss: 8.6055e-04
# Epoch 21/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0025 - val_loss: 9.7859e-04
# Epoch 22/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0030 - val_loss: 7.9496e-04
# Epoch 23/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0028 - val_loss: 0.0010
# Epoch 24/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0022 - val_loss: 0.0013
# Epoch 25/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0028 - val_loss: 0.0012
# Epoch 26/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0025 - val_loss: 7.6577e-04
# Epoch 27/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0024 - val_loss: 0.0014
# Epoch 28/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0025 - val_loss: 0.0024
# Epoch 29/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0028 - val_loss: 7.2502e-04
# Epoch 30/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0022 - val_loss: 0.0011
# Epoch 31/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0026 - val_loss: 9.3936e-04
# Epoch 32/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0028 - val_loss: 8.1726e-04
# Epoch 33/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0024 - val_loss: 7.0985e-04
# Epoch 34/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0022 - val_loss: 0.0012
# Epoch 35/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0028 - val_loss: 8.0044e-04
# Epoch 36/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0022 - val_loss: 7.8853e-04
# Epoch 37/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0021 - val_loss: 6.6718e-04
# Epoch 38/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0017 - val_loss: 6.7399e-04
# Epoch 39/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0022 - val_loss: 6.8256e-04
# Epoch 40/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0021 - val_loss: 6.6151e-04
# Epoch 41/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0023 - val_loss: 7.5122e-04
# Epoch 42/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0027 - val_loss: 0.0014
# Epoch 43/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0030 - val_loss: 0.0011
# Epoch 44/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0028 - val_loss: 9.7033e-04
# Epoch 45/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0024 - val_loss: 6.7179e-04
# Epoch 46/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0024 - val_loss: 6.3581e-04
# Epoch 47/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0022 - val_loss: 0.0011
# Epoch 48/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0022 - val_loss: 9.6815e-04
# Epoch 49/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0023 - val_loss: 6.1345e-04
# Epoch 50/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0021 - val_loss: 9.7535e-04
# Epoch 51/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0023 - val_loss: 6.1772e-04
# Epoch 52/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0019 - val_loss: 7.1714e-04
# Epoch 53/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0018 - val_loss: 6.4558e-04
# Epoch 54/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0017 - val_loss: 5.7341e-04
# Epoch 55/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0020 - val_loss: 5.9946e-04
# Epoch 56/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0020 - val_loss: 5.8531e-04
# Epoch 57/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0022 - val_loss: 0.0016
# Epoch 58/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0021 - val_loss: 5.3745e-04
# Epoch 59/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0019 - val_loss: 8.6769e-04
# Epoch 60/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0017 - val_loss: 0.0016
# Epoch 61/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0022 - val_loss: 6.1085e-04
# Epoch 62/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0018 - val_loss: 7.1731e-04
# Epoch 63/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0022 - val_loss: 5.1803e-04
# Epoch 64/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0019 - val_loss: 5.4830e-04
# Epoch 65/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0019 - val_loss: 5.5299e-04
# Epoch 66/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0019 - val_loss: 5.8942e-04
# Epoch 67/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0014 - val_loss: 6.2423e-04
# Epoch 68/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0015 - val_loss: 4.9298e-04
# Epoch 69/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0021 - val_loss: 7.8856e-04
# Epoch 70/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0017 - val_loss: 5.2109e-04
# Epoch 71/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0015 - val_loss: 4.9095e-04
# Epoch 72/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0016 - val_loss: 4.6300e-04
# Epoch 73/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0016 - val_loss: 8.8828e-04
# Epoch 74/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0015 - val_loss: 5.4212e-04
# Epoch 75/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0016 - val_loss: 4.4983e-04
# Epoch 76/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0017 - val_loss: 5.6683e-04
# Epoch 77/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0016 - val_loss: 4.4164e-04
# Epoch 78/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0017 - val_loss: 4.6229e-04
# Epoch 79/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0015 - val_loss: 0.0011
# Epoch 80/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0017 - val_loss: 4.2510e-04
# Epoch 81/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0014 - val_loss: 5.2323e-04
# Epoch 82/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0015 - val_loss: 7.0610e-04
# Epoch 83/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0014 - val_loss: 4.0714e-04
# Epoch 84/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0014 - val_loss: 4.3156e-04
# Epoch 85/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0017 - val_loss: 0.0013
# Epoch 86/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0015 - val_loss: 5.0555e-04
# Epoch 87/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0013 - val_loss: 4.1717e-04
# Epoch 88/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0015 - val_loss: 4.8362e-04
# Epoch 89/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0014 - val_loss: 3.7093e-04
# Epoch 90/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0013 - val_loss: 4.3591e-04
# Epoch 91/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0014 - val_loss: 4.0754e-04
# Epoch 92/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0019 - val_loss: 3.7952e-04
# Epoch 93/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0014 - val_loss: 4.9132e-04
# Epoch 94/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0014 - val_loss: 4.1738e-04
# Epoch 95/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0011 - val_loss: 6.4817e-04
# Epoch 96/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0012 - val_loss: 3.9630e-04
# Epoch 97/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0012 - val_loss: 4.8623e-04
# Epoch 98/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0014 - val_loss: 5.8653e-04
# Epoch 99/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0013 - val_loss: 4.8669e-04
# Epoch 100/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0015 - val_loss: 4.6757e-04
# Waktu training: 58.73 detik

# %%
plt.plot(model_adro.history.history['loss'], label='Training Loss')
plt.plot(model_adro.history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %% [markdown]
# ### Make predictions

# %%
y_pred_adro = model_adro.predict(X_test_adro)
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step

# %% [markdown]
# ## DSSA

# %%
model_dssa = create_lstm_model(50)

start_time = time.time()
model_dssa.fit(X_train_dssa, y_train_dssa, epochs=100, batch_size=32, validation_split=0.1)

end_time = time.time()
elapsed_time = end_time - start_time

print(f"Waktu training: {elapsed_time:.2f} detik")
# Out:
# Epoch 1/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 34ms/step - loss: 0.0011 - val_loss: 2.2276e-05
# Epoch 2/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 6.8414e-05 - val_loss: 2.2902e-05
# Epoch 3/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 4.5363e-05 - val_loss: 2.3395e-05
# Epoch 4/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 4.3452e-05 - val_loss: 3.1975e-05
# Epoch 5/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 4.3499e-05 - val_loss: 2.4126e-05
# Epoch 6/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 4.5167e-05 - val_loss: 2.1645e-05
# Epoch 7/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 4.1128e-05 - val_loss: 2.4966e-05
# Epoch 8/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 3.3168e-05 - val_loss: 2.3491e-05
# Epoch 9/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 3.7528e-05 - val_loss: 6.1096e-05
# Epoch 10/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 4.8742e-05 - val_loss: 2.2061e-05
# Epoch 11/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 3.1275e-05 - val_loss: 4.0077e-05
# Epoch 12/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 3.7202e-05 - val_loss: 2.0323e-05
# Epoch 13/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 3.8073e-05 - val_loss: 2.9048e-05
# Epoch 14/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 4.1807e-05 - val_loss: 2.0463e-05
# Epoch 15/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 3.3603e-05 - val_loss: 1.9372e-05
# Epoch 16/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 2.7459e-05 - val_loss: 1.9056e-05
# Epoch 17/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 3.1397e-05 - val_loss: 2.9013e-05
# Epoch 18/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 3.7765e-05 - val_loss: 2.0759e-05
# Epoch 19/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 2.7533e-05 - val_loss: 3.3268e-05
# Epoch 20/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 3.3001e-05 - val_loss: 2.9803e-05
# Epoch 21/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.9535e-05 - val_loss: 4.4241e-05
# Epoch 22/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 3.1945e-05 - val_loss: 2.6201e-05
# Epoch 23/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 3.8563e-05 - val_loss: 2.2679e-05
# Epoch 24/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 2.6621e-05 - val_loss: 1.7631e-05
# Epoch 25/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 3.0659e-05 - val_loss: 1.9095e-05
# Epoch 26/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.9203e-05 - val_loss: 2.6965e-05
# Epoch 27/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 2.8240e-05 - val_loss: 1.9071e-05
# Epoch 28/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 3.4100e-05 - val_loss: 1.9557e-05
# Epoch 29/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.6700e-05 - val_loss: 1.6884e-05
# Epoch 30/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 2.9941e-05 - val_loss: 1.6666e-05
# Epoch 31/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 2.8295e-05 - val_loss: 1.8493e-05
# Epoch 32/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 2.1054e-05 - val_loss: 1.8256e-05
# Epoch 33/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 2.8208e-05 - val_loss: 2.1414e-05
# Epoch 34/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 2.3298e-05 - val_loss: 1.6437e-05
# Epoch 35/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 2.4681e-05 - val_loss: 1.5853e-05
# Epoch 36/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 2.5298e-05 - val_loss: 1.5562e-05
# Epoch 37/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 2.2451e-05 - val_loss: 1.8615e-05
# Epoch 38/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.5531e-05 - val_loss: 1.4722e-05
# Epoch 39/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.0735e-05 - val_loss: 2.8358e-05
# Epoch 40/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 2.3460e-05 - val_loss: 2.6814e-05
# Epoch 41/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 2.0410e-05 - val_loss: 1.2920e-05
# Epoch 42/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.4813e-05 - val_loss: 2.3090e-05
# Epoch 43/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.5645e-05 - val_loss: 1.4176e-05
# Epoch 44/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.0451e-05 - val_loss: 1.2723e-05
# Epoch 45/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 2.7947e-05 - val_loss: 1.6429e-05
# Epoch 46/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.8350e-05 - val_loss: 1.2462e-05
# Epoch 47/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.5319e-05 - val_loss: 1.2044e-05
# Epoch 48/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.1819e-05 - val_loss: 1.3440e-05
# Epoch 49/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 2.2723e-05 - val_loss: 2.2385e-05
# Epoch 50/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 2.5924e-05 - val_loss: 1.2031e-05
# Epoch 51/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 2.3586e-05 - val_loss: 1.1036e-05
# Epoch 52/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.8777e-05 - val_loss: 1.6900e-05
# Epoch 53/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.9838e-05 - val_loss: 2.0602e-05
# Epoch 54/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.8073e-05 - val_loss: 1.1176e-05
# Epoch 55/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.2104e-05 - val_loss: 1.7115e-05
# Epoch 56/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 1.8079e-05 - val_loss: 1.1157e-05
# Epoch 57/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.1138e-05 - val_loss: 1.4089e-05
# Epoch 58/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.8922e-05 - val_loss: 1.7836e-05
# Epoch 59/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 2.2425e-05 - val_loss: 1.0023e-05
# Epoch 60/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 1.4936e-05 - val_loss: 9.7403e-06
# Epoch 61/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 1.6731e-05 - val_loss: 1.2815e-05
# Epoch 62/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.8145e-05 - val_loss: 1.2641e-05
# Epoch 63/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 2.0398e-05 - val_loss: 9.6773e-06
# Epoch 64/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.7398e-05 - val_loss: 1.3879e-05
# Epoch 65/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 2.8225e-05 - val_loss: 9.1334e-06
# Epoch 66/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.4935e-05 - val_loss: 2.7951e-05
# Epoch 67/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 2.7208e-05 - val_loss: 1.1204e-05
# Epoch 68/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 1.9572e-05 - val_loss: 2.0409e-05
# Epoch 69/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.0810e-05 - val_loss: 1.2169e-05
# Epoch 70/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.0301e-05 - val_loss: 1.2232e-05
# Epoch 71/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.7950e-05 - val_loss: 1.1885e-05
# Epoch 72/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 1.9908e-05 - val_loss: 9.7562e-06
# Epoch 73/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.7178e-05 - val_loss: 9.0335e-06
# Epoch 74/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.9939e-05 - val_loss: 9.3443e-06
# Epoch 75/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.5937e-05 - val_loss: 8.0504e-06
# Epoch 76/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.0187e-05 - val_loss: 8.5234e-06
# Epoch 77/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 2.1466e-05 - val_loss: 2.1305e-05
# Epoch 78/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 2.0094e-05 - val_loss: 1.4212e-05
# Epoch 79/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 1.9985e-05 - val_loss: 1.6003e-05
# Epoch 80/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.3180e-05 - val_loss: 7.4696e-06
# Epoch 81/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 2.0226e-05 - val_loss: 7.3601e-06
# Epoch 82/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 2.4888e-05 - val_loss: 7.8342e-06
# Epoch 83/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.9924e-05 - val_loss: 8.1027e-06
# Epoch 84/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 2.1235e-05 - val_loss: 8.4539e-06
# Epoch 85/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.8082e-05 - val_loss: 1.2898e-05
# Epoch 86/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.7205e-05 - val_loss: 8.0767e-06
# Epoch 87/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.7948e-05 - val_loss: 1.2041e-05
# Epoch 88/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.5960e-05 - val_loss: 1.4046e-05
# Epoch 89/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 2.3590e-05 - val_loss: 1.0555e-05
# Epoch 90/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 1.8822e-05 - val_loss: 6.7689e-06
# Epoch 91/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.4831e-05 - val_loss: 1.2298e-05
# Epoch 92/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.4361e-05 - val_loss: 6.8960e-06
# Epoch 93/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.3375e-05 - val_loss: 8.0097e-06
# Epoch 94/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 1.5113e-05 - val_loss: 7.2169e-06
# Epoch 95/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 2.2038e-05 - val_loss: 1.1126e-05
# Epoch 96/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 1.4942e-05 - val_loss: 7.1321e-06
# Epoch 97/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.7796e-05 - val_loss: 2.0359e-05
# Epoch 98/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 2.0270e-05 - val_loss: 1.1171e-05
# Epoch 99/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 1.6048e-05 - val_loss: 8.0023e-06
# Epoch 100/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 1.4381e-05 - val_loss: 7.0396e-06
# Waktu training: 55.95 detik

# %%
plt.plot(model_dssa.history.history['loss'], label='Training Loss')
plt.plot(model_dssa.history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %% [markdown]
# ### Make predictions

# %%
y_pred_dssa = model_dssa.predict(X_test_dssa)
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step

# %% [markdown]
# ## Evaluate Model

# %%
def evaluate_model(y_true, y_pred):
    rmse = np.sqrt(mean_squared_error(y_true, y_pred))
    mape = np.mean(np.abs((y_true - y_pred) / y_true)) * 100
    r2 = r2_score(y_true, y_pred)

    print(f'RMSE: {rmse:.3f}')
    print(f'MAPE: {mape:.3f}%')
    print(f'R-squared: {r2:.5f}')

    return rmse, mape, r2

# %%
# Evaluate ADRO model
print("Evaluation for ADRO:")
rmse_adro, mape_adro, r2_adro = evaluate_model(y_test_adro, y_pred_adro)

# Evaluate DSSA model
print("\nEvaluation for DSSA:")
rmse_dssa, mape_dssa, r2_dssa = evaluate_model(y_test_dssa, y_pred_dssa)
# Out:
# Evaluation for ADRO:
# RMSE: 0.023
# MAPE: 17.146%
# R-squared: 0.95282
#
# Evaluation for DSSA:
# RMSE: 0.054
# MAPE: 111.451%
# R-squared: 0.96334

# %% [markdown]
# ## Plot the predicted vs actual values

# %%
def plot_predictions(y_true, y_pred, title):
    plt.figure(figsize=(10, 6))
    plt.plot(y_true, label='Actual Price', color='orange')
    plt.plot(y_pred, label='Predicted Price', color='green')
    plt.title(title)
    plt.xlabel('Time')
    plt.ylabel('Price')
    plt.legend()
    plt.show()

# %%
# Plot ADRO predictions
plot_predictions(y_test_adro, y_pred_adro, 'ADRO Predicted vs Actual Prices')

# %%
plot_predictions(y_test_dssa, y_pred_dssa, 'DSSA Predicted vs Actual Prices')
