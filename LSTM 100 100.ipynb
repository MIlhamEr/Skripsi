# %% [markdown]
# <a href="https://colab.research.google.com/github/MIlhamEr/Skripsi/blob/main/LSTM%20100%20100.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Import Libraries

# %%
import time
import numpy as np
import pandas as pd
import seaborn as sns
import missingno as msno
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %% [markdown]
# # Reading Dataset

# %% [markdown]
# ## ADRO

# %%
url_adro = "https://raw.githubusercontent.com/MIlhamEr/Skripsi/refs/heads/main/dataset/PT%20Adaro%20Energy%20Indonesia%20Tbk_2020-2024.csv"
adro = pd.read_csv(url_adro)
adro.head()
# Out:
#          Date    Open    High     Low   Close   Adj Close     Volume
# 0  2020-01-02  1555.0  1555.0  1490.0  1495.0  835.632202   76612000
# 1  2020-01-03  1460.0  1470.0  1425.0  1465.0  856.372375  117795600
# 2  2020-01-06  1455.0  1515.0  1450.0  1465.0  856.372375   61423200
# 3  2020-01-07  1480.0  1540.0  1460.0  1540.0  900.213867   74336500
# 4  2020-01-08  1530.0  1535.0  1505.0  1505.0  879.754395   55121100

# %%
adro.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1148 entries, 0 to 1147
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       1148 non-null   object
#  1   Open       1148 non-null   float64
#  2   High       1148 non-null   float64
#  3   Low        1148 non-null   float64
#  4   Close      1148 non-null   float64
#  5   Adj Close  1148 non-null   float64
#  6   Volume     1148 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 62.9+ KB

# %% [markdown]
# ## DSSA

# %%
url_dssa = "https://raw.githubusercontent.com/MIlhamEr/Skripsi/refs/heads/main/dataset/PT%20Dian%20Swastatika%20Sentosa%20Tbk_2020-2024.csv"
dssa = pd.read_csv(url_dssa)
dssa.head()
# Out:
#          Date    Open    High     Low   Close  Adj Close  Volume
# 0  2020-01-02  1360.0  1435.0  1360.0  1435.0     1435.0    5000
# 1  2020-01-03  1435.0  1435.0  1435.0  1435.0     1435.0       0
# 2  2020-01-06  1437.5  1437.5  1435.0  1435.0     1435.0    3000
# 3  2020-01-07  1435.0  1435.0  1435.0  1435.0     1435.0       0
# 4  2020-01-08  1435.0  1435.0  1435.0  1435.0     1435.0       0

# %%
dssa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1148 entries, 0 to 1147
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       1148 non-null   object
#  1   Open       1148 non-null   float64
#  2   High       1148 non-null   float64
#  3   Low        1148 non-null   float64
#  4   Close      1148 non-null   float64
#  5   Adj Close  1148 non-null   float64
#  6   Volume     1148 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 62.9+ KB

# %% [markdown]
# # Pre-processing Data

# %% [markdown]
# ## Normalisasi Data

# %% [markdown]
# *   Normalisasi data adro pake MinMaxScaler karena distribusinya normal
# *   Normalisasi data dssa pake StandardScaler karena terdapat outlier
# *   Kolom Date Ga dipake

# %%
scaler = MinMaxScaler()

# %%
def normalize_data(df):
    scaled_df = pd.DataFrame(scaler.fit_transform(df.iloc[:, 1:]), columns=df.columns[1:], index=df.index)
    return scaled_df

# %%
adro_norm = adro.copy()
adro_norm = normalize_data(adro_norm)
adro_norm = adro_norm.drop('Volume', axis=1)
adro_norm.head()
# Out:
#        Open      High       Low     Close  Adj Close
# 0  0.260372  0.247207  0.253602  0.243205   0.129805
# 1  0.233190  0.223464  0.234870  0.234621   0.135675
# 2  0.231760  0.236034  0.242075  0.234621   0.135675
# 3  0.238913  0.243017  0.244957  0.256080   0.148084
# 4  0.253219  0.241620  0.257925  0.246066   0.142293

# %%
dssa_norm = dssa.copy()
dssa_norm = normalize_data(dssa_norm)
dssa_norm = dssa_norm.drop('Volume', axis=1)
dssa_norm.head()
# Out:
#        Open      High       Low     Close  Adj Close
# 0  0.010859  0.011743  0.011073  0.012575   0.012575
# 1  0.012669  0.011743  0.012918  0.012575   0.012575
# 2  0.012729  0.011800  0.012918  0.012575   0.012575
# 3  0.012669  0.011743  0.012918  0.012575   0.012575
# 4  0.012669  0.011743  0.012918  0.012575   0.012575

# %% [markdown]
# ## Windowing (Time Series Data)

# %% [markdown]
# Data look back yaitu adalah data yang biasanya dipakai untuk tipe time series, data ini menjadikan nilai lookback+1 sebagai nilai prediksi , dan data lookbacknya sebagai fitur.Ini berlaku untuk seluruh data, contoh penggambarannya seperti pada gambar diatas

# %%
def prepare_data(df, time_step):
    X, y = [], []
    for i in range(len(df)-time_step):
        t = []
        for j in range(time_step):
            t.append(df.iloc[i + j].values)  # Use all columns for features
        X.append(t)
        y.append(df['High'][i + time_step]) # Predict High price
    return np.array(X), np.array(y)

# %%
time_step = 7
X_adro, y_adro = prepare_data(adro_norm, time_step)

# %%
print(X_adro)
print(y_adro)
# Out:
# [[[0.26037196 0.2472067  0.25360231 0.24320458 0.12980455]
#   [0.23319027 0.22346369 0.23487032 0.23462089 0.13567503]
#   [0.23175966 0.23603352 0.24207493 0.23462089 0.13567503]
#   ...
#   [0.25321888 0.24162011 0.25792507 0.24606581 0.14229328]
#   [0.25035765 0.23882682 0.24927954 0.24320458 0.14063873]
#   [0.25035765 0.25       0.26080692 0.25894134 0.14973887]]
#
#  [[0.23319027 0.22346369 0.23487032 0.23462089 0.13567503]
#   [0.23175966 0.23603352 0.24207493 0.23462089 0.13567503]
#   [0.23891273 0.24301676 0.24495677 0.25608011 0.1480843 ]
#   ...
#   [0.25035765 0.23882682 0.24927954 0.24320458 0.14063873]
#   [0.25035765 0.25       0.26080692 0.25894134 0.14973887]
#   [0.26895565 0.25837989 0.27233429 0.26323319 0.15222076]]
#
#  [[0.23175966 0.23603352 0.24207493 0.23462089 0.13567503]
#   [0.23891273 0.24301676 0.24495677 0.25608011 0.1480843 ]
#   [0.25321888 0.24162011 0.25792507 0.24606581 0.14229328]
#   ...
#   [0.25035765 0.25       0.26080692 0.25894134 0.14973887]
#   [0.26895565 0.25837989 0.27233429 0.26323319 0.15222076]
#   [0.26752504 0.25558659 0.26657061 0.26180258 0.15139345]]
#
#  ...
#
#  [[0.91416309 0.88547486 0.87896254 0.86552217 0.93206834]
#   [0.86552217 0.86871508 0.85302594 0.89127325 0.95754271]
#   [0.89127325 0.86871508 0.87319885 0.85979971 0.92640737]
#   ...
#   [0.86552217 0.8575419  0.87319885 0.87124464 0.93772931]
#   [0.87982833 0.8575419  0.88760807 0.87410587 0.9405598 ]
#   [0.88268956 0.86312849 0.88760807 0.88555079 0.95188174]]
#
#  [[0.86552217 0.86871508 0.85302594 0.89127325 0.95754271]
#   [0.89127325 0.86871508 0.87319885 0.85979971 0.92640737]
#   [0.86266094 0.84636872 0.85590778 0.86266094 0.92923785]
#   ...
#   [0.87982833 0.8575419  0.88760807 0.87410587 0.9405598 ]
#   [0.88268956 0.86312849 0.88760807 0.88555079 0.95188174]
#   [0.89127325 0.86312849 0.88472622 0.87124464 0.93772931]]
#
#  [[0.89127325 0.86871508 0.87319885 0.85979971 0.92640737]
#   [0.86266094 0.84636872 0.85590778 0.86266094 0.92923785]
#   [0.86552217 0.8575419  0.87319885 0.87124464 0.93772931]
#   ...
#   [0.88268956 0.86312849 0.88760807 0.88555079 0.95188174]
#   [0.89127325 0.86312849 0.88472622 0.87124464 0.93772931]
#   [0.87982833 0.86871508 0.89048991 0.89699571 0.96320368]]]
# [0.25837989 0.25558659 0.2472067  ... 0.86312849 0.86871508 0.91340782]

# %%
X_adro.shape, y_adro.shape
# Out:
# ((1141, 7, 5), (1141,))

# %%
X_dssa, y_dssa = prepare_data(dssa_norm, time_step)

# %% [markdown]
# ## Split data into training and testing sets

# %%
X_train_adro, X_test_adro, y_train_adro, y_test_adro = train_test_split(X_adro, y_adro, test_size=0.2, random_state=42, shuffle=False)
X_train_dssa, X_test_dssa, y_train_dssa, y_test_dssa = train_test_split(X_dssa, y_dssa, test_size=0.2, random_state=42, shuffle=False)

# %%
X_train_adro.shape, X_test_adro.shape, y_train_adro.shape, y_test_adro.shape
# Out:
# ((912, 7, 5), (229, 7, 5), (912,), (229,))

# %% [markdown]
# # Data Mining

# %%
def create_lstm_model(units):
    model = Sequential()
    model.add(LSTM(units=units, return_sequences=True, input_shape=(X_train_adro.shape[1], X_train_adro.shape[2])))
    model.add(Dropout(0.2))
    model.add(LSTM(units=units, return_sequences=False))
    model.add(Dropout(0.2))
    model.add(Dense(units=1))  # Output layer for single prediction (predicted stock price)
    model.compile(optimizer='adam', loss='mean_squared_error')
    return model

# %% [markdown]
# ## ADRO

# %%
model_adro = create_lstm_model(100)

start_time = time.time()
model_adro.fit(X_train_adro, y_train_adro, epochs=100, batch_size=32, validation_split=0.1)

end_time = time.time()
elapsed_time = end_time - start_time

print(f"Waktu training: {elapsed_time:.2f} detik")
# Out:
# Epoch 1/100
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 5s 48ms/step - loss: 0.0734 - val_loss: 0.0047
# Epoch 2/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0043 - val_loss: 0.0014
# Epoch 3/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0025 - val_loss: 0.0011
# Epoch 4/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0028 - val_loss: 7.6742e-04
# Epoch 5/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0029 - val_loss: 7.6858e-04
# Epoch 6/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0024 - val_loss: 0.0018
# Epoch 7/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0022 - val_loss: 0.0011
# Epoch 8/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0021 - val_loss: 9.7119e-04
# Epoch 9/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0017 - val_loss: 7.4195e-04
# Epoch 10/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0023 - val_loss: 8.3227e-04
# Epoch 11/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0024 - val_loss: 0.0016
# Epoch 12/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0023 - val_loss: 0.0014
# Epoch 13/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0021 - val_loss: 0.0013
# Epoch 14/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0020 - val_loss: 7.2180e-04
# Epoch 15/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0021 - val_loss: 0.0030
# Epoch 16/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0021 - val_loss: 0.0011
# Epoch 17/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0017 - val_loss: 9.2746e-04
# Epoch 18/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0024 - val_loss: 0.0029
# Epoch 19/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0027 - val_loss: 9.1161e-04
# Epoch 20/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0021 - val_loss: 6.9504e-04
# Epoch 21/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0020 - val_loss: 8.1629e-04
# Epoch 22/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0017 - val_loss: 6.3845e-04
# Epoch 23/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0019 - val_loss: 6.8400e-04
# Epoch 24/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0020 - val_loss: 6.3771e-04
# Epoch 25/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0022 - val_loss: 0.0011
# Epoch 26/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0020 - val_loss: 0.0011
# Epoch 27/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0021 - val_loss: 0.0010
# Epoch 28/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0018 - val_loss: 8.1985e-04
# Epoch 29/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0016 - val_loss: 6.1239e-04
# Epoch 30/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0021 - val_loss: 5.9487e-04
# Epoch 31/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0014 - val_loss: 6.7040e-04
# Epoch 32/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0016 - val_loss: 5.6775e-04
# Epoch 33/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0016 - val_loss: 6.2153e-04
# Epoch 34/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0017 - val_loss: 7.8229e-04
# Epoch 35/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0017 - val_loss: 5.3869e-04
# Epoch 36/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0014 - val_loss: 5.1682e-04
# Epoch 37/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0016 - val_loss: 0.0022
# Epoch 38/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0018 - val_loss: 5.5209e-04
# Epoch 39/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0016 - val_loss: 0.0014
# Epoch 40/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0017 - val_loss: 7.7380e-04
# Epoch 41/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0016 - val_loss: 5.4058e-04
# Epoch 42/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0016 - val_loss: 4.6953e-04
# Epoch 43/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0019 - val_loss: 5.3565e-04
# Epoch 44/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0015 - val_loss: 6.1413e-04
# Epoch 45/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0015 - val_loss: 0.0010
# Epoch 46/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0011 - val_loss: 0.0014
# Epoch 47/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0020 - val_loss: 4.5673e-04
# Epoch 48/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0016 - val_loss: 8.8313e-04
# Epoch 49/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0014 - val_loss: 4.8707e-04
# Epoch 50/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0014 - val_loss: 4.2172e-04
# Epoch 51/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0013 - val_loss: 5.2492e-04
# Epoch 52/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0015 - val_loss: 4.4555e-04
# Epoch 53/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0016 - val_loss: 5.2536e-04
# Epoch 54/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0014 - val_loss: 6.1787e-04
# Epoch 55/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0013 - val_loss: 5.7906e-04
# Epoch 56/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0014 - val_loss: 4.3854e-04
# Epoch 57/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0014 - val_loss: 6.2869e-04
# Epoch 58/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0015 - val_loss: 7.7173e-04
# Epoch 59/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0015 - val_loss: 6.1649e-04
# Epoch 60/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0012 - val_loss: 3.6089e-04
# Epoch 61/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0012 - val_loss: 5.4200e-04
# Epoch 62/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0011 - val_loss: 5.0458e-04
# Epoch 63/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0012 - val_loss: 9.7698e-04
# Epoch 64/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0014 - val_loss: 3.7346e-04
# Epoch 65/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 9.4680e-04 - val_loss: 6.9573e-04
# Epoch 66/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0015 - val_loss: 3.2886e-04
# Epoch 67/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0012 - val_loss: 3.6180e-04
# Epoch 68/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0016 - val_loss: 5.7405e-04
# Epoch 69/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0015 - val_loss: 3.2771e-04
# Epoch 70/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0014 - val_loss: 3.9689e-04
# Epoch 71/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0010 - val_loss: 3.3903e-04
# Epoch 72/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0012 - val_loss: 3.3967e-04
# Epoch 73/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0012 - val_loss: 6.3696e-04
# Epoch 74/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0011 - val_loss: 9.1499e-04
# Epoch 75/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.0012 - val_loss: 5.8695e-04
# Epoch 76/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0013 - val_loss: 3.0564e-04
# Epoch 77/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0012 - val_loss: 5.5923e-04
# Epoch 78/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0011 - val_loss: 0.0015
# Epoch 79/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0013 - val_loss: 4.1014e-04
# Epoch 80/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0011 - val_loss: 3.9939e-04
# Epoch 81/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0011 - val_loss: 8.2819e-04
# Epoch 82/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0012 - val_loss: 2.9719e-04
# Epoch 83/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 9.6811e-04 - val_loss: 3.1028e-04
# Epoch 84/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 8.2989e-04 - val_loss: 2.9478e-04
# Epoch 85/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 9.1974e-04 - val_loss: 2.9776e-04
# Epoch 86/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0011 - val_loss: 3.5441e-04
# Epoch 87/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0014 - val_loss: 3.4580e-04
# Epoch 88/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 9.4178e-04 - val_loss: 4.1116e-04
# Epoch 89/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 9.4041e-04 - val_loss: 3.1946e-04
# Epoch 90/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 8.3672e-04 - val_loss: 2.9684e-04
# Epoch 91/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 8.6399e-04 - val_loss: 2.7623e-04
# Epoch 92/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 9.8626e-04 - val_loss: 2.6715e-04
# Epoch 93/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0011 - val_loss: 2.9506e-04
# Epoch 94/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 9.6857e-04 - val_loss: 4.5128e-04
# Epoch 95/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0010 - val_loss: 6.0428e-04
# Epoch 96/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0012 - val_loss: 2.7027e-04
# Epoch 97/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 9.9929e-04 - val_loss: 2.5577e-04
# Epoch 98/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 9.7545e-04 - val_loss: 2.7412e-04
# Epoch 99/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0010 - val_loss: 4.0419e-04
# Epoch 100/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 8.7369e-04 - val_loss: 2.9682e-04
# Waktu training: 66.11 detik

# %%
plt.plot(model_adro.history.history['loss'], label='Training Loss')
plt.plot(model_adro.history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %% [markdown]
# ### Make predictions

# %%
y_pred_adro = model_adro.predict(X_test_adro)
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step

# %% [markdown]
# ## DSSA

# %%
model_dssa = create_lstm_model(100)

start_time = time.time()
model_dssa.fit(X_train_dssa, y_train_dssa, epochs=100, batch_size=32, validation_split=0.1)

end_time = time.time()
elapsed_time = end_time - start_time

print(f"Waktu training: {elapsed_time:.2f} detik")
# Out:
# Epoch 1/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - loss: 7.8340e-04 - val_loss: 6.8511e-05
# Epoch 2/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 5.5784e-05 - val_loss: 2.1386e-05
# Epoch 3/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 4.3108e-05 - val_loss: 2.1929e-05
# Epoch 4/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 3.8283e-05 - val_loss: 2.5462e-05
# Epoch 5/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 3.2959e-05 - val_loss: 2.7721e-05
# Epoch 6/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 3.7624e-05 - val_loss: 2.0834e-05
# Epoch 7/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 2.8645e-05 - val_loss: 2.4321e-05
# Epoch 8/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 3.1578e-05 - val_loss: 1.9445e-05
# Epoch 9/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 3.1628e-05 - val_loss: 2.1965e-05
# Epoch 10/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 2.8916e-05 - val_loss: 1.8385e-05
# Epoch 11/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 2.6885e-05 - val_loss: 2.9270e-05
# Epoch 12/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 3.0858e-05 - val_loss: 1.8258e-05
# Epoch 13/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 3.4191e-05 - val_loss: 2.9553e-05
# Epoch 14/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 2.8972e-05 - val_loss: 1.7539e-05
# Epoch 15/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 2.9699e-05 - val_loss: 2.9058e-05
# Epoch 16/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 3.0470e-05 - val_loss: 1.8648e-05
# Epoch 17/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 2.5597e-05 - val_loss: 1.7116e-05
# Epoch 18/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 2.5891e-05 - val_loss: 3.4312e-05
# Epoch 19/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 3.4127e-05 - val_loss: 4.4672e-05
# Epoch 20/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 2.7669e-05 - val_loss: 3.2456e-05
# Epoch 21/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 2.6448e-05 - val_loss: 3.1488e-05
# Epoch 22/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 3.2011e-05 - val_loss: 1.5272e-05
# Epoch 23/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 2.0908e-05 - val_loss: 4.1722e-05
# Epoch 24/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 2.4287e-05 - val_loss: 1.4034e-05
# Epoch 25/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 2.5844e-05 - val_loss: 1.3313e-05
# Epoch 26/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 2.3914e-05 - val_loss: 1.5138e-05
# Epoch 27/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 2.2181e-05 - val_loss: 1.3354e-05
# Epoch 28/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2.3792e-05 - val_loss: 2.1299e-05
# Epoch 29/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 2.2924e-05 - val_loss: 2.0596e-05
# Epoch 30/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 2.1608e-05 - val_loss: 1.4648e-05
# Epoch 31/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 2.0167e-05 - val_loss: 1.6074e-05
# Epoch 32/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 2.2714e-05 - val_loss: 3.5591e-05
# Epoch 33/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 2.6795e-05 - val_loss: 1.5006e-05
# Epoch 34/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 2.0518e-05 - val_loss: 1.1003e-05
# Epoch 35/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 1.7474e-05 - val_loss: 1.1819e-05
# Epoch 36/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.7355e-05 - val_loss: 1.3317e-05
# Epoch 37/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 1.5001e-05 - val_loss: 1.2824e-05
# Epoch 38/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 2.0598e-05 - val_loss: 1.8445e-05
# Epoch 39/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 2.6985e-05 - val_loss: 1.8030e-05
# Epoch 40/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 1.9754e-05 - val_loss: 2.0666e-05
# Epoch 41/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.7713e-05 - val_loss: 1.2518e-05
# Epoch 42/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2.3128e-05 - val_loss: 3.7368e-05
# Epoch 43/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 1.8456e-05 - val_loss: 9.1808e-06
# Epoch 44/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 1.6061e-05 - val_loss: 9.0086e-06
# Epoch 45/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 1.5243e-05 - val_loss: 2.0923e-05
# Epoch 46/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.8721e-05 - val_loss: 1.8701e-05
# Epoch 47/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 2.1366e-05 - val_loss: 1.3172e-05
# Epoch 48/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.5891e-05 - val_loss: 8.6374e-06
# Epoch 49/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 1.6810e-05 - val_loss: 8.1572e-06
# Epoch 50/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.5891e-05 - val_loss: 1.0886e-05
# Epoch 51/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 1.7563e-05 - val_loss: 1.0601e-05
# Epoch 52/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 1.9279e-05 - val_loss: 1.2583e-05
# Epoch 53/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 1.5002e-05 - val_loss: 8.0794e-06
# Epoch 54/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.3967e-05 - val_loss: 7.7196e-06
# Epoch 55/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 1.5731e-05 - val_loss: 8.1414e-06
# Epoch 56/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.4470e-05 - val_loss: 1.3482e-05
# Epoch 57/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.9433e-05 - val_loss: 4.1185e-05
# Epoch 58/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2.2033e-05 - val_loss: 8.2599e-06
# Epoch 59/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.4079e-05 - val_loss: 7.0255e-06
# Epoch 60/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.5995e-05 - val_loss: 8.8725e-06
# Epoch 61/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 1.8152e-05 - val_loss: 1.4571e-05
# Epoch 62/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 1.2897e-05 - val_loss: 8.1015e-06
# Epoch 63/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.4888e-05 - val_loss: 2.3259e-05
# Epoch 64/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.3853e-05 - val_loss: 7.2186e-06
# Epoch 65/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.8480e-05 - val_loss: 7.9164e-06
# Epoch 66/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.4212e-05 - val_loss: 6.3145e-06
# Epoch 67/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.5164e-05 - val_loss: 6.3463e-06
# Epoch 68/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.2704e-05 - val_loss: 1.1573e-05
# Epoch 69/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.2715e-05 - val_loss: 7.6699e-06
# Epoch 70/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 1.6398e-05 - val_loss: 6.2870e-06
# Epoch 71/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.2328e-05 - val_loss: 6.0598e-06
# Epoch 72/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 1.3100e-05 - val_loss: 6.2021e-06
# Epoch 73/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 1.5479e-05 - val_loss: 1.0865e-05
# Epoch 74/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 1.3824e-05 - val_loss: 6.4066e-06
# Epoch 75/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.4974e-05 - val_loss: 6.8215e-06
# Epoch 76/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.2206e-05 - val_loss: 9.6254e-06
# Epoch 77/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.7692e-05 - val_loss: 6.5512e-06
# Epoch 78/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.4911e-05 - val_loss: 6.4943e-06
# Epoch 79/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.4527e-05 - val_loss: 5.7452e-06
# Epoch 80/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 1.2718e-05 - val_loss: 5.5579e-06
# Epoch 81/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.2795e-05 - val_loss: 6.8533e-06
# Epoch 82/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 1.4777e-05 - val_loss: 5.5346e-06
# Epoch 83/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.1923e-05 - val_loss: 7.1074e-06
# Epoch 84/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.3602e-05 - val_loss: 5.2038e-06
# Epoch 85/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 1.1854e-05 - val_loss: 5.1642e-06
# Epoch 86/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.4604e-05 - val_loss: 1.0771e-05
# Epoch 87/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 1.2329e-05 - val_loss: 6.1109e-06
# Epoch 88/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.3406e-05 - val_loss: 6.7242e-06
# Epoch 89/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.6568e-05 - val_loss: 1.4267e-05
# Epoch 90/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.2935e-05 - val_loss: 5.8300e-06
# Epoch 91/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 1.1166e-05 - val_loss: 6.8783e-06
# Epoch 92/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 1.4583e-05 - val_loss: 4.8928e-06
# Epoch 93/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 1.0651e-05 - val_loss: 6.2786e-06
# Epoch 94/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 1.1584e-05 - val_loss: 5.3996e-06
# Epoch 95/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.4271e-05 - val_loss: 8.5300e-06
# Epoch 96/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 1.2321e-05 - val_loss: 6.2981e-06
# Epoch 97/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.4288e-05 - val_loss: 4.9308e-06
# Epoch 98/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.3752e-05 - val_loss: 4.9021e-06
# Epoch 99/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 1.4644e-05 - val_loss: 5.9819e-06
# Epoch 100/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 1.3563e-05 - val_loss: 1.3384e-05
# Waktu training: 66.14 detik

# %%
plt.plot(model_dssa.history.history['loss'], label='Training Loss')
plt.plot(model_dssa.history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %% [markdown]
# ### Make predictions

# %%
y_pred_dssa = model_dssa.predict(X_test_dssa)
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step

# %% [markdown]
# ## Evaluate Model

# %%
def evaluate_model(y_true, y_pred):
    rmse = np.sqrt(mean_squared_error(y_true, y_pred))
    mape = np.mean(np.abs((y_true - y_pred) / y_true)) * 100
    r2 = r2_score(y_true, y_pred)

    print(f'RMSE: {rmse:.3f}')
    print(f'MAPE: {mape:.3f}%')
    print(f'R-squared: {r2:.5f}')

    return rmse, mape, r2

# %%
# Evaluate ADRO model
print("Evaluation for ADRO:")
rmse_adro, mape_adro, r2_adro = evaluate_model(y_test_adro, y_pred_adro)

# Evaluate DSSA model
print("\nEvaluation for DSSA:")
rmse_dssa, mape_dssa, r2_dssa = evaluate_model(y_test_dssa, y_pred_dssa)
# Out:
# Evaluation for ADRO:
# RMSE: 0.019
# MAPE: 17.394%
# R-squared: 0.96590
#
# Evaluation for DSSA:
# RMSE: 0.040
# MAPE: 115.020%
# R-squared: 0.98021

# %% [markdown]
# ## Plot the predicted vs actual values

# %%
def plot_predictions(y_true, y_pred, title):
    plt.figure(figsize=(10, 6))
    plt.plot(y_true, label='Actual Price', color='orange')
    plt.plot(y_pred, label='Predicted Price', color='green')
    plt.title(title)
    plt.xlabel('Time')
    plt.ylabel('Price')
    plt.legend()
    plt.show()

# %%
# Plot ADRO predictions
plot_predictions(y_test_adro, y_pred_adro, 'ADRO Predicted vs Actual Prices')

# %%
plot_predictions(y_test_dssa, y_pred_dssa, 'DSSA Predicted vs Actual Prices')
