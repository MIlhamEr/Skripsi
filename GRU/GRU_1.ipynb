# %% [markdown]
# <a href="https://colab.research.google.com/github/MIlhamEr/Skripsi/blob/main/GRU_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Import Libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import missingno as msno
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import GRU, Dense, Dropout
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %% [markdown]
# # Import Function

# %%
def plot_stock_data(df, title):
    plt.figure(figsize=(20, 5))

    # Subplot 1: Harga Open Close saham
    plt.subplot(1, 3, 1)
    plt.plot(df['Date'].values, df.Open.values, color='red', label='Open')
    plt.plot(df['Date'].values, df.Close.values, color='cyan', label='Close')
    plt.xticks(np.arange(100,df.shape[0],200), rotation=20)
    plt.title(f'{title} Open Close Price')
    plt.xlabel('Date')
    plt.ylabel('Price')
    plt.legend(loc='best')

    # Subplot 1: Harga Low High saham
    plt.subplot(1, 3, 2)
    plt.plot(df['Date'].values, df.Low.values, color='green', label='Low')
    plt.plot(df['Date'].values, df.High.values, color='yellow', label='High')
    plt.xticks(np.arange(100,df.shape[0],200), rotation=20)
    plt.title(f'{title} Low High Price')
    plt.xlabel('Date')
    plt.ylabel('Price')
    plt.legend(loc='best')

    # Subplot 3: Volume saham
    plt.subplot(1, 3, 3)
    plt.plot(df['Date'].values, df.Volume.values, color='black', label='Volume')
    plt.xticks(np.arange(100,df.shape[0],200), rotation=20)
    plt.title(f'{title} Stock Volume')
    plt.xlabel('Date')
    plt.ylabel('Volume')
    plt.legend(loc='best')

    plt.show()

# %% [markdown]
# # Reading Dataset

# %% [markdown]
# ## ADRO

# %%
url_adro = "https://raw.githubusercontent.com/MIlhamEr/Skripsi/refs/heads/main/dataset/PT%20Adaro%20Energy%20Indonesia%20Tbk_2020-2024.csv"
adro = pd.read_csv(url_adro)
adro.head()
# Out:
#          Date    Open    High     Low   Close   Adj Close     Volume
# 0  2020-01-02  1555.0  1555.0  1490.0  1495.0  835.632202   76612000
# 1  2020-01-03  1460.0  1470.0  1425.0  1465.0  856.372375  117795600
# 2  2020-01-06  1455.0  1515.0  1450.0  1465.0  856.372375   61423200
# 3  2020-01-07  1480.0  1540.0  1460.0  1540.0  900.213867   74336500
# 4  2020-01-08  1530.0  1535.0  1505.0  1505.0  879.754395   55121100

# %%
adro.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1148 entries, 0 to 1147
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       1148 non-null   object
#  1   Open       1148 non-null   float64
#  2   High       1148 non-null   float64
#  3   Low        1148 non-null   float64
#  4   Close      1148 non-null   float64
#  5   Adj Close  1148 non-null   float64
#  6   Volume     1148 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 62.9+ KB

# %%
plot_stock_data(adro, "Adaro Energy Indonesia Tbk")

# %% [markdown]
# ## DSSA

# %%
url_dssa = "https://raw.githubusercontent.com/MIlhamEr/Skripsi/refs/heads/main/dataset/PT%20Dian%20Swastatika%20Sentosa%20Tbk_2020-2024.csv"
dssa = pd.read_csv(url_dssa)
dssa.head()
# Out:
#          Date    Open    High     Low   Close  Adj Close  Volume
# 0  2020-01-02  1360.0  1435.0  1360.0  1435.0     1435.0    5000
# 1  2020-01-03  1435.0  1435.0  1435.0  1435.0     1435.0       0
# 2  2020-01-06  1437.5  1437.5  1435.0  1435.0     1435.0    3000
# 3  2020-01-07  1435.0  1435.0  1435.0  1435.0     1435.0       0
# 4  2020-01-08  1435.0  1435.0  1435.0  1435.0     1435.0       0

# %%
dssa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1148 entries, 0 to 1147
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       1148 non-null   object
#  1   Open       1148 non-null   float64
#  2   High       1148 non-null   float64
#  3   Low        1148 non-null   float64
#  4   Close      1148 non-null   float64
#  5   Adj Close  1148 non-null   float64
#  6   Volume     1148 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 62.9+ KB

# %%
plot_stock_data(dssa, "Dian Swastatika Sentosa Tbk")

# %% [markdown]
# # Pre-processing Data

# %% [markdown]
# ## Cleaning Dataset

# %%
adro_missing = adro.isnull().sum()
dssa_missing = dssa.isnull().sum()

print("Missing values in ADRO:")
print(adro_missing)
print("\nMissing values in DSSA:")
print(dssa_missing)
# Out:
# Missing values in ADRO:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
#
# Missing values in DSSA:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %% [markdown]
# ## Normalisasi Data

# %% [markdown]
# *   Normalisasi data pake MinMaxScaler
# *   Kolom Date Ga dipake

# %%
scaler = MinMaxScaler()

# %%
def normalize_data(df):
    scaled_df = pd.DataFrame(scaler.fit_transform(df.iloc[:, 1:]), columns=df.columns[1:], index=df.index)
    return scaled_df

# %%
adro_norm = adro.copy()
adro_norm = normalize_data(adro_norm)

# %%
dssa_norm = dssa.copy()
dssa_norm = normalize_data(dssa_norm)

# %%
adro_norm.head()
# Out:
#        Open      High       Low     Close  Adj Close    Volume
# 0  0.260372  0.247207  0.253602  0.243205   0.129805  0.141875
# 1  0.233190  0.223464  0.234870  0.234621   0.135675  0.218142
# 2  0.231760  0.236034  0.242075  0.234621   0.135675  0.113748
# 3  0.238913  0.243017  0.244957  0.256080   0.148084  0.137661
# 4  0.253219  0.241620  0.257925  0.246066   0.142293  0.102077

# %%
dssa_norm.head()
# Out:
#        Open      High       Low     Close  Adj Close    Volume
# 0  0.010859  0.011743  0.011073  0.012575   0.012575  0.000417
# 1  0.012669  0.011743  0.012918  0.012575   0.012575  0.000000
# 2  0.012729  0.011800  0.012918  0.012575   0.012575  0.000250
# 3  0.012669  0.011743  0.012918  0.012575   0.012575  0.000000
# 4  0.012669  0.011743  0.012918  0.012575   0.012575  0.000000

# %% [markdown]
# # Data Mining

# %% [markdown]
# ## Preprocessing Data

# %% [markdown]
# Model GRU memerlukan data time series, jadi kita perlu membuat window (misalnya 30 hari ke belakang untuk memprediksi harga di hari ke-31).

# %%
def create_sequences(data, time_steps):
    X, y = [], []
    for i in range(len(data) - time_steps -1): # Fixed : Subtracted 1 to avoid index error
        X.append(data.iloc[i:i+time_steps].values) # Changed: use iloc to access rows and convert to NumPy array
        y.append(data.iloc[i+time_steps, 0])       # Changed: use iloc to access row and column by index
    return np.array(X), np.array(y)

# %% [markdown]
# # ADRO

# %%
time_steps = 30
X, y = create_sequences(adro_norm, time_steps)

# %% [markdown]
# ## Target Attribute
#
# Dipilih atribut "high" sebagai target prediksi

# %%
adro["High"][:918].plot(figsize=(16,4),legend=True)
adro["High"][918:].plot(figsize=(16,4),legend=True)
plt.legend(['Training set','Test set'])
plt.title('IBM stock price')
plt.show()

# %% [markdown]
# ## Pembagian Data

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=False)

# %% [markdown]
# ## Model GRU

# %%
model = Sequential()
model.add(GRU(units=50, return_sequences=True, input_shape=(X_train.shape[1], X_train.shape[2])))
model.add(Dropout(0.2))
model.add(GRU(units=50))
model.add(Dropout(0.2))
model.add(Dense(units=1)) # Output layer with 1 neuron for regression
model.compile(optimizer='adam', loss='mean_squared_error')
model.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ gru_6 (GRU)                          │ (None, 30, 50)              │           8,700 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_6 (Dropout)                  │ (None, 30, 50)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ gru_7 (GRU)                          │ (None, 50)                  │          15,300 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_7 (Dropout)                  │ (None, 50)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 1)                   │              51 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 24,051 (93.95 KB)
#  Trainable params: 24,051 (93.95 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## Training Model

# %%
history = model.fit(X_train, y_train, epochs=50, batch_size=32, validation_split=0.1)
# Out:
# Epoch 1/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 8s 59ms/step - loss: 0.0248 - val_loss: 9.2766e-04
# Epoch 2/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.0070 - val_loss: 4.4308e-04
# Epoch 3/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.0049 - val_loss: 3.0468e-04
# Epoch 4/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 0.0035 - val_loss: 9.3493e-04
# Epoch 5/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 0.0039 - val_loss: 3.5511e-04
# Epoch 6/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 62ms/step - loss: 0.0027 - val_loss: 4.4140e-04
# Epoch 7/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step - loss: 0.0029 - val_loss: 3.1789e-04
# Epoch 8/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - loss: 0.0036 - val_loss: 0.0012
# Epoch 9/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - loss: 0.0031 - val_loss: 5.9073e-04
# Epoch 10/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 0.0029 - val_loss: 2.8137e-04
# Epoch 11/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0026 - val_loss: 6.2359e-04
# Epoch 12/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - loss: 0.0022 - val_loss: 2.3481e-04
# Epoch 13/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 98ms/step - loss: 0.0026 - val_loss: 4.3866e-04
# Epoch 14/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.0026 - val_loss: 2.4340e-04
# Epoch 15/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 0.0021 - val_loss: 5.9001e-04
# Epoch 16/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 0.0022 - val_loss: 3.3660e-04
# Epoch 17/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.0024 - val_loss: 5.4890e-04
# Epoch 18/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.0029 - val_loss: 3.8669e-04
# Epoch 19/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.0025 - val_loss: 4.4993e-04
# Epoch 20/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.0022 - val_loss: 3.5749e-04
# Epoch 21/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.0021 - val_loss: 0.0026
# Epoch 22/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.0027 - val_loss: 2.1301e-04
# Epoch 23/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - loss: 0.0017 - val_loss: 0.0019
# Epoch 24/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 63ms/step - loss: 0.0029 - val_loss: 0.0023
# Epoch 25/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - loss: 0.0025 - val_loss: 0.0013
# Epoch 26/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.0022 - val_loss: 0.0012
# Epoch 27/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.0020 - val_loss: 6.9978e-04
# Epoch 28/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 0.0022 - val_loss: 4.5680e-04
# Epoch 29/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.0020 - val_loss: 5.6746e-04
# Epoch 30/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.0017 - val_loss: 3.3382e-04
# Epoch 31/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.0025 - val_loss: 2.1714e-04
# Epoch 32/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 0.0029 - val_loss: 5.8570e-04
# Epoch 33/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 62ms/step - loss: 0.0030 - val_loss: 5.2936e-04
# Epoch 34/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - loss: 0.0021 - val_loss: 4.8095e-04
# Epoch 35/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.0023 - val_loss: 4.5072e-04
# Epoch 36/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.0022 - val_loss: 1.7137e-04
# Epoch 37/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 0.0018 - val_loss: 3.6304e-04
# Epoch 38/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.0019 - val_loss: 1.7467e-04
# Epoch 39/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.0017 - val_loss: 2.4939e-04
# Epoch 40/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0017 - val_loss: 3.5095e-04
# Epoch 41/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.0018 - val_loss: 3.9320e-04
# Epoch 42/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0014 - val_loss: 8.1719e-04
# Epoch 43/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 66ms/step - loss: 0.0018 - val_loss: 5.1457e-04
# Epoch 44/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 0.0016 - val_loss: 1.4575e-04
# Epoch 45/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.0015 - val_loss: 4.6619e-04
# Epoch 46/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0018 - val_loss: 0.0018
# Epoch 47/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.0022 - val_loss: 1.9014e-04
# Epoch 48/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 0.0016 - val_loss: 1.7768e-04
# Epoch 49/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.0014 - val_loss: 2.2383e-04
# Epoch 50/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.0014 - val_loss: 1.4689e-04

# %% [markdown]
# ## Plot training history

# %%
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(loc='upper right')
plt.show()

# %% [markdown]
# ## Prediction

# %%
y_pred = model.predict(X_test)
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step

# %% [markdown]
# ## Inverse Transform

# %%
y_pred = scaler.inverse_transform(np.concatenate((y_pred, np.zeros((len(y_pred), adro_norm.shape[1] - 1))), axis=1))[:,0]
y_test = scaler.inverse_transform(np.concatenate((y_test.reshape(-1,1), np.zeros((len(y_test), adro_norm.shape[1] - 1))), axis=1))[:,0]

# %% [markdown]
# ## Evaluation Metrics

# %%
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)

print(f'Mean Absolute Error (MAE): {mae:.2f}')
print(f'Mean Squared Error (MSE): {mse:.2f}')
print(f'Root Mean Squared Error (RMSE): {rmse:.2f}')
print(f'R-squared (R2): {r2:.2f}')
# Out:
# Mean Absolute Error (MAE): 438.30
# Mean Squared Error (MSE): 449563.39
# Root Mean Squared Error (RMSE): 670.49
# R-squared (R2): 0.98

# %% [markdown]
# ## Plot the predicted vs actual values

# %%
plt.figure(figsize=(10, 6))
plt.plot(y_test, label='Actual')
plt.plot(y_pred, label='Predicted')
plt.title('Actual vs Predicted Stock Prices (High)')
plt.xlabel('Time')
plt.ylabel('Stock Price')
plt.legend()
plt.show()

# %% [markdown]
# # DSSA

# %%
time_steps = 30
X, y = create_sequences(dssa_norm, time_steps)

# %% [markdown]
# ## Target Attribute

# %%
dssa["High"][:918].plot(figsize=(16,4),legend=True)
dssa["High"][918:].plot(figsize=(16,4),legend=True)
plt.legend(['Training set','Test set'])
plt.title('IBM stock price')
plt.show()

# %% [markdown]
# ##Pembagian Data

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=False)

# %% [markdown]
# ## Model GRU

# %%
model = Sequential()
model.add(GRU(units=50, return_sequences=True, input_shape=(X_train.shape[1], X_train.shape[2])))
model.add(Dropout(0.2))
model.add(GRU(units=50))
model.add(Dropout(0.2))
model.add(Dense(units=1)) # Output layer with 1 neuron for regression
model.compile(optimizer='adam', loss='mean_squared_error')
model.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ gru_8 (GRU)                          │ (None, 30, 50)              │           8,700 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_8 (Dropout)                  │ (None, 30, 50)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ gru_9 (GRU)                          │ (None, 50)                  │          15,300 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_9 (Dropout)                  │ (None, 50)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (None, 1)                   │              51 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 24,051 (93.95 KB)
#  Trainable params: 24,051 (93.95 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## Training Model

# %%
history = model.fit(X_train, y_train, epochs=50, batch_size=32, validation_split=0.1)
# Out:
# Epoch 1/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 6s 76ms/step - loss: 3.1722e-04 - val_loss: 2.5050e-05
# Epoch 2/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 117ms/step - loss: 6.9438e-05 - val_loss: 1.5640e-05
# Epoch 3/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - loss: 6.4482e-05 - val_loss: 2.0851e-05
# Epoch 4/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 63ms/step - loss: 4.1053e-05 - val_loss: 4.8947e-05
# Epoch 5/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 77ms/step - loss: 4.6985e-05 - val_loss: 2.8778e-05
# Epoch 6/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 67ms/step - loss: 4.1735e-05 - val_loss: 4.0490e-05
# Epoch 7/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 81ms/step - loss: 3.5618e-05 - val_loss: 5.4196e-05
# Epoch 8/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 3.4695e-05 - val_loss: 4.3909e-05
# Epoch 9/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 3.2840e-05 - val_loss: 6.8364e-05
# Epoch 10/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 66ms/step - loss: 4.3746e-05 - val_loss: 6.3057e-05
# Epoch 11/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - loss: 2.4132e-05 - val_loss: 8.5290e-05
# Epoch 12/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 3.1322e-05 - val_loss: 8.8194e-05
# Epoch 13/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 2.7216e-05 - val_loss: 8.6944e-05
# Epoch 14/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 2.4740e-05 - val_loss: 9.1873e-05
# Epoch 15/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - loss: 2.7584e-05 - val_loss: 1.2104e-04
# Epoch 16/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - loss: 2.6067e-05 - val_loss: 1.7039e-04
# Epoch 17/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - loss: 2.5636e-05 - val_loss: 1.2492e-04
# Epoch 18/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 2.3168e-05 - val_loss: 1.4131e-04
# Epoch 19/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 2.0186e-05 - val_loss: 1.5121e-04
# Epoch 20/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 72ms/step - loss: 1.7675e-05 - val_loss: 1.7777e-04
# Epoch 21/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 2.3083e-05 - val_loss: 1.7202e-04
# Epoch 22/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - loss: 3.0749e-05 - val_loss: 1.5917e-04
# Epoch 23/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 72ms/step - loss: 1.8593e-05 - val_loss: 1.4096e-04
# Epoch 24/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 68ms/step - loss: 1.8161e-05 - val_loss: 1.5322e-04
# Epoch 25/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 1.9196e-05 - val_loss: 1.6740e-04
# Epoch 26/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 1.6401e-05 - val_loss: 2.3921e-04
# Epoch 27/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 1.8701e-05 - val_loss: 1.9516e-04
# Epoch 28/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 1.6564e-05 - val_loss: 1.8152e-04
# Epoch 29/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 1.8010e-05 - val_loss: 1.8182e-04
# Epoch 30/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 65ms/step - loss: 1.4871e-05 - val_loss: 1.9924e-04
# Epoch 31/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 62ms/step - loss: 1.8870e-05 - val_loss: 1.7939e-04
# Epoch 32/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 98ms/step - loss: 1.4348e-05 - val_loss: 1.8604e-04
# Epoch 33/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 1.7552e-05 - val_loss: 1.8510e-04
# Epoch 34/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 1.8088e-05 - val_loss: 1.7220e-04
# Epoch 35/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 1.5060e-05 - val_loss: 1.7688e-04
# Epoch 36/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 1.6104e-05 - val_loss: 1.7745e-04
# Epoch 37/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 2.2528e-05 - val_loss: 1.5784e-04
# Epoch 38/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - loss: 1.6614e-05 - val_loss: 1.7201e-04
# Epoch 39/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 1.5963e-05 - val_loss: 1.5817e-04
# Epoch 40/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 65ms/step - loss: 2.3651e-05 - val_loss: 1.4906e-04
# Epoch 41/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 71ms/step - loss: 1.6930e-05 - val_loss: 1.4298e-04
# Epoch 42/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 1.2471e-05 - val_loss: 1.4717e-04
# Epoch 43/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 1.4395e-05 - val_loss: 1.5788e-04
# Epoch 44/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 1.6658e-05 - val_loss: 1.5871e-04
# Epoch 45/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 1.6553e-05 - val_loss: 1.8606e-04
# Epoch 46/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - loss: 2.3305e-05 - val_loss: 1.8247e-04
# Epoch 47/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 1.3959e-05 - val_loss: 1.7411e-04
# Epoch 48/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 76ms/step - loss: 1.3190e-05 - val_loss: 1.8316e-04
# Epoch 49/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 56ms/step - loss: 1.4647e-05 - val_loss: 2.0779e-04
# Epoch 50/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 1.3337e-05 - val_loss: 2.0730e-04

# %% [markdown]
# ## Plot training history

# %%
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(loc='upper right')
plt.show()

# %% [markdown]
# ##Prediction

# %%
y_pred = model.predict(X_test)
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step

# %% [markdown]
# ## Inverse Transform

# %%
y_pred = scaler.inverse_transform(np.concatenate((y_pred, np.zeros((len(y_pred), adro_norm.shape[1] - 1))), axis=1))[:,0]
y_test = scaler.inverse_transform(np.concatenate((y_test.reshape(-1,1), np.zeros((len(y_test), adro_norm.shape[1] - 1))), axis=1))[:,0]

# %% [markdown]
# Evaluatione Metrics

# %%
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)

print(f'Mean Absolute Error (MAE): {mae:.2f}')
print(f'Mean Squared Error (MSE): {mse:.2f}')
print(f'Root Mean Squared Error (RMSE): {rmse:.2f}')
print(f'R-squared (R2): {r2:.2f}')
# Out:
# Mean Absolute Error (MAE): 518.45
# Mean Squared Error (MSE): 553193.62
# Root Mean Squared Error (RMSE): 743.77
# R-squared (R2): 1.00

# %% [markdown]
# ## Plot the predicted vs actual values

# %%
plt.figure(figsize=(10, 6))
plt.plot(y_test, label='Actual')
plt.plot(y_pred, label='Predicted')
plt.title('Actual vs Predicted Stock Prices (High)')
plt.xlabel('Time')
plt.ylabel('Stock Price')
plt.legend()
plt.show()
